# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov3u.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 198M/198M [01:51<00:00, 1.87MB/s]

# %%
# Train the model
results = model.train(data="./data/dfg-ultralytics/data.yaml", epochs=1, imgsz=640)
# Out:
# Ultralytics 8.3.94  Python-3.12.0 torch-2.6.0+cpu CPU (Intel Core(TM) i7-10510U 1.80GHz)
# ...
